# %%
import pandas as pd
df=pd.read_csv('company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
import matplotlib.pyplot as plt

fig=plt.figure()

plt.xlim(0,13)
plt.ylim(100000,500000)
plt.xlabel('Month Number', fontsize=12)
plt.ylabel('Total Profit', fontsize=12)

plt.title('Company Profit Per Month', fontsize=14)
plt.xticks(df['month_number'])

plt.plot(df['month_number'], df['total_profit'])
plt.show()

# %% [markdown]
# #Question3

# %%
import matplotlib.pyplot as plt

fig=plt.figure()

plt.xlim(0,13)
plt.ylim(100000,500000)
plt.xlabel('Month Number', fontsize=12)
plt.ylabel('Solid units number', fontsize=12)

plt.title('Company Sales data of last year', fontsize=14)
plt.xticks(df['month_number'])


plt.plot(df['month_number'], df['total_profit'], linestyle='dotted', color='red', label='Profit data of last year', linewidth=3, marker='o', markerfacecolor='red')

plt.legend(loc='lower right')

# %%
import matplotlib.pyplot as plt
fig=plt.figure()

plt.xlim(0,13)
plt.ylim(1000,18000)
plt.xlabel('Month Number', fontsize=10)
plt.ylabel('Sales units in number', fontsize=10)

plt.title('Sales data', fontsize=12)
plt.xticks(df['month_number'])


facecream=plt.plot(df['month_number'], df['facecream'], marker='o', linewidth=2.5)
facewash=plt.plot(df['month_number'], df['facewash'], marker='o', linewidth=2.5)
toothpaste=plt.plot(df['month_number'], df['toothpaste'], marker='o', linewidth=2.5)
bathingsoap=plt.plot(df['month_number'], df['bathingsoap'], marker='o', linewidth=2.5)

shampoo=plt.plot(df['month_number'], df['shampoo'], marker='o', linewidth=2.5)
moisturizer=plt.plot(df['month_number'], df['moisturizer'], marker='o', linewidth=2.5)

# %%
import matplotlib.pyplot as plt

fig=plt.figure()

plt.xlim(0,13)
plt.ylim(0,15000)
plt.xlabel('Month Number', fontsize=12)
plt.ylabel('Sales units in number', fontsize=12)

plt.title('Bathingsoap sales data', fontsize=14)
plt.xticks(df['month_number'])
plt.grid(which='major')

plt.bar(df['month_number'], df['bathingsoap'])
# Out:
# <BarContainer object of 12 artists>
